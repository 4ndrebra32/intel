# %% [markdown]
# <a href="https://colab.research.google.com/github/4ndrebra32/intel/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Métricas avanzadas: permiten evaluar el rendimiento de los modelos mediante medidas como la matriz de confusión, la precisión y exhaustividad (recall), la puntuación F1-Score y las curvas ROC y área bajo la curva (AUC).
Truco del Kernel: consiste en transformar los datos hacia dimensiones superiores para facilitar la separación de datos que no pueden dividirse correctamente en el espacio original. Es una técnica relacionada con métodos como las máquinas de vectores de soporte (SVM).
Preprocesamiento de datos: antes de analizar los datos, se pueden realizar diferentes transformaciones:
Imputación: tratamiento y relleno de datos faltantes.
Escalamiento: normalización de las escalas o unidades de las variables.
Reducción: compresión o disminución de la dimensionalidad de los datos.
Clasificador: estimación del tipo o categoría a la que pertenece cada dato.

En conjunto, estos procedimientos permiten preparar los datos, reducir problemas derivados de sus características y evaluar qué tan bien funciona un modelo predictivo.

# %% [markdown]
# Métricas avanzadas: permiten evaluar el rendimiento de los modelos mediante medidas como la matriz de confusión, la precisión y exhaustividad (recall), la puntuación F1-Score y las curvas ROC y área bajo la curva (AUC).
# Truco del Kernel: consiste en transformar los datos hacia dimensiones superiores para facilitar la separación de datos que no pueden dividirse correctamente en el espacio original. Es una técnica relacionada con métodos como las máquinas de vectores de soporte (SVM).
# Preprocesamiento de datos: antes de analizar los datos, se pueden realizar diferentes transformaciones:
# Imputación: tratamiento y relleno de datos faltantes.
# Escalamiento: normalización de las escalas o unidades de las variables.
# Reducción: compresión o disminución de la dimensionalidad de los datos.
# Clasificador: estimación del tipo o categoría a la que pertenece cada dato.
#
# En conjunto, estos procedimientos permiten preparar los datos, reducir problemas derivados de sus características y evaluar qué tan bien funciona un modelo predictivo.
